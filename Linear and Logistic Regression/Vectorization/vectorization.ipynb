# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the seed for reproducibility
np.random.seed(42)

# Number of samples and features
num_samples = 100
num_features = 3

# Generate random x values (features)
x_train = 2 * np.random.rand(num_samples, num_features)

# Define true weights (slopes) and intercept
true_weights = np.array([[3], [2], [1]])  # shape: (3, 1)
true_intercept = 4

# Generate noise
noise = np.random.randn(num_samples, 1)

# Compute y values
y_train = true_intercept + x_train @ true_weights + noise  # @ is matrix multiplication

# Plotting using only first feature for visualization
plt.figure(figsize=(8, 5))
plt.scatter(x_train[:, 0], y_train, color="green", label="Training data (vs 1st feature)", alpha=0.7)
plt.title("Dummy Linear Regression Data (3 features)")
plt.xlabel("x_train[:, 0] (1st feature)")
plt.ylabel("y_train")
plt.legend()
plt.grid(True)
plt.show()

print("Features shape is:", x_train.shape)
print("Target shape is:", y_train.shape)
# Out:
# Features shape is: (100, 3)
# Target shape is: (100, 1)

# %%
iteration = len(x_train)
b = 3
learning_rate = 0.01
m = len(x_train)
w = np.array([[2],[3],[4]])
cost_ = []
for _ in range(iteration):
    yp = x_train @ w + b

    # ---- Cost Function (MSE) ----
    cost = np.mean((yp - y_train) ** 2) / 2
    cost_.append(cost)

    # ---- Gradients ----
    dw =  (np.transpose(x_train) @ (yp - y_train)) / m
    db = np.sum((yp - y_train)) / m
    
    # ---- Update Parameters ----
    w = w - learning_rate * dw
    b = b - learning_rate * db 

    if _ % 10 == 0:
        print(f"Iteration {_}: Cost = {cost:.4f}")
# Out:
# Iteration 0: Cost = 4.1137
# Iteration 10: Cost = 2.7062
# Iteration 20: Cost = 2.0644
# Iteration 30: Cost = 1.7501
# Iteration 40: Cost = 1.5775
# Iteration 50: Cost = 1.4676
# Iteration 60: Cost = 1.3867
# Iteration 70: Cost = 1.3205
# Iteration 80: Cost = 1.2626
# Iteration 90: Cost = 1.2103

# %%
# Plot cost vs iterations
plt.figure(figsize=(6, 4))
plt.plot(cost_, linewidth=2) 
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.title("Cost Reduction Over Time")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
